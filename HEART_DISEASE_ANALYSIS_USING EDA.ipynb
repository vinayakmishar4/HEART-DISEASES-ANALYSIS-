# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# # Distrbution Plot for the heart disease depends on the age factor, cholesterol level and blood pressure and ETC

# %%
sns.displot(df['Age'])

# %%
sns.displot(df['Cholesterol'])

# %%
sns.displot(df['MaxHR'])

# %%
sns.displot(df['RestingBP'])

# %% [markdown]
# # ANALYSIS SOME CATEGORICAL DATA

# %%
df.groupby(df['Sex']).size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby(df['Sex']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby(df['HeartDisease']).size()
# Out:
# HeartDisease
# 0    410
# 1    508
# dtype: int64

# %%
df.groupby(df['HeartDisease']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby(df['ChestPainType']).size()
# Out:
# ChestPainType
# ASY    496
# ATA    173
# NAP    203
# TA      46
# dtype: int64

# %%
df.groupby(df['ChestPainType']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby(df['ExerciseAngina']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby(df['RestingECG']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df.groupby(df['ST_Slope']).size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# # ANALYSIS ON THE BASIS OF DIFFERNET FACTOR

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# Male are most infected or comes under infection of heart disease as compare with women

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# Heart Disease case will come at age of above 55 years to 65 and 58 to 63 year human being higher chance of heart Diseases

# %%
sns.violinplot(y=df['Cholesterol'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
df_numerical = df.select_dtypes(include=['number'])

# %%
df_numerical.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0

# %%
Matrix=df_numerical.corr()

# %%
sns.heatmap(Matrix)
# Out:
# <Axes: >

# %% [markdown]
# According to this heatmap, I can see that heart disease and heart rate are negatively correlated. This means that if the heart rate per minute decreases, the chances of heart disease increase.

# %%
sns.jointplot(data=df,x=df['Age'],y=df['MaxHR'],kind='reg')

# %% [markdown]
# If age is inceraseing then hreat rate is decaresing

# %%
sns.jointplot(data=df,x=df['HeartDisease'],y=df['Oldpeak'])

# %%
sns.jointplot(data=df,y=df['HeartDisease'],x=df['MaxHR'])

# %% [markdown]
# Maximun heart rate btween 140 to 160 can incerase the heart diseases

# %%
sns.pairplot(df)
